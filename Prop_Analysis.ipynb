# %% [markdown]
# ## My Prop Notebook
# by Debby Oh
# This was done as part of a Python for Data Journalists course in July 2017

# %%
import pandas as pd

# %% [markdown]
# Reading in the CSVs

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head(10)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7  ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8  ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9  ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.groupby("prop_name_x").amount.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-3796edc16bd6> in <module>()
# ----> 1 props.groupby("prop_name_x").amount.sum()
#
# /Users/debbyoh/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Users/debbyoh/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
# ...

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()

# %%
contribs.info()

# %%
merged = pd.merge(props, contribs, on="calaccess_committee_id")

# %%
merged.groupby("committee_name_x").amount.sum()

# %%
props.prop_name.value_counts().reset_index()merged.groupby("committee_name_x").amount.sum()

# %%
contribs.contributor_occupation.value_counts().reset_index()

# %%
props.prop_name.value_counts()

# %%
prop = props[props.prop_name == "PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE."]

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 63  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 64  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 65  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 66  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 67  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#     ccdc_prop_id                                          prop_name  \
# 63            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 64            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 65            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 66            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 67            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 63                445                 1380590
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 63 to 69
# Data columns (total 8 columns):
# ocd_prop_id               7 non-null object
# calaccess_prop_id         7 non-null int64
# ccdc_prop_id              7 non-null int64
# prop_name                 7 non-null object
# ccdc_committee_id         7 non-null int64
# calaccess_committee_id    7 non-null int64
# committee_name            7 non-null object
# committee_position        7 non-null object
# dtypes: int64(4), object(4)
# memory usage: 504.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 1  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 2  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 3  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 4  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#    ccdc_prop_id                                          prop_name  \
# 0            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 1            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 2            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 3            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 4            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                445                 1380590
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34442 entries, 0 to 34441
# Data columns (total 20 columns):
# ocd_prop_id                     34442 non-null object
# calaccess_prop_id               34442 non-null int64
# ccdc_prop_id                    34442 non-null int64
# prop_name                       34442 non-null object
# ccdc_committee_id               34442 non-null int64
# calaccess_committee_id          34442 non-null int64
# committee_name_x                34442 non-null object
# committee_position              34442 non-null object
# committee_name_y                34442 non-null object
# calaccess_filing_id             34442 non-null int64
# date_received                   34442 non-null object
# contributor_lastname            34438 non-null object
# contributor_firstname           33920 non-null object
# contributor_city                34434 non-null object
# contributor_state               34432 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 32836678.18

# %%
merged.committee_position.value_counts()
# Out:
# OPPOSE     29633
# SUPPORT     4809
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.amount.sum()
# Out:
# 16000608.370000001

# %%
oppose.amount.sum()
# Out:
# 16836069.809999999

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.48727853293472212

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 1863   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1972   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2026   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1967   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1851   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1547   ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 1973   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1980   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1968   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
oppose.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 1972   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1967   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1973   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1980   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1968   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 3087   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3075   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3046   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3066   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3080   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount",ascending=False)
# Out:
#                                     committee_name_x        amount
# 1  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  8.387852e+06
# 0  CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  8.343218e+06
# 6  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...  7.621678e+06
# 2       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  6.140000e+06
# 3  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  2.110000e+06
# 5                           VOLUNTEERS FOR YES ON 62  1.289300e+05
# 4  SAN FRANCISCO POLICE OFFICERS ASSOCIATION ISSU...  1.050000e+05

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount",ascending=False)
# Out:
#       contributor_firstname contributor_lastname committee_position     amount
# 28396                THOMAS               STEYER            SUPPORT  1750000.0
# 21812              NICHOLAS              MCKEOWN            SUPPORT  1500000.0
# 23740                  REED             HASTINGS            SUPPORT  1000000.0
# 22511                  PAUL               GRAHAM            SUPPORT   500000.0
# 17405               L. JOHN                DOERR            SUPPORT   500000.0
# 11192              HENRY T.         NICHOLAS III             OPPOSE   400000.0
# 16162                 JULIE             MOTAMEDI             OPPOSE   350000.0
# 24680           ROBERT ALAN              EUSTACE            SUPPORT   175000.0
# 27966                 SUSAN                GROFF             OPPOSE   160000.0
# 24276            RICHARD J.              RIORDAN             OPPOSE   100000.0
# 18793                  MARC              BENIOFF            SUPPORT   100000.0
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90264 entries, 0 to 90263
# Data columns (total 20 columns):
# ocd_prop_id                     90264 non-null object
# calaccess_prop_id               90264 non-null int64
# ccdc_prop_id                    90264 non-null int64
# prop_name                       90264 non-null object
# ccdc_committee_id               90264 non-null int64
# calaccess_committee_id          90264 non-null int64
# committee_name_x                90264 non-null object
# committee_position              90264 non-null object
# committee_name_y                90264 non-null object
# calaccess_filing_id             90264 non-null int64
# date_received                   90264 non-null object
# contributor_lastname            90256 non-null object
# contributor_firstname           86685 non-null object
# contributor_city                90251 non-null object
# contributor_state               90244 non-null object
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
merged.
# Out:
#   File "<ipython-input-45-142345daa510>", line 1
#     merged.
#            ^
# SyntaxError: invalid syntax
